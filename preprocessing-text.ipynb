# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
kalimat = ["elearning di PTTIK diatas jam 6 malam kok selalu gak bisa dibuka ya?",
           "ub tidak punya lahan parkir yang layak. Dan jalanan terlalu ramai karena di buka untuk umum. Seperti jalan tol saja. Brawijaya oh brawijaya",
           "Kelas Arsitektur dan Organisasi Komputer penuh, apakah tidak dibuka kelas lagi. Rugi kalo saya bisa ngambil 24 SKS tapi baru 18 SKS yg terpenuhi",
           "Informasi tata cara daftar ulang bagi mahasiswa baru PTIIK kurang jelas. Sehingga ketika tanggal terakhir syarat penyerahan berkas daftar ulang, banyak mahasiswa baru yang tidak membawa salah satu syarat daftar ulangnya."]

# %% [markdown]
# Text Lowercase

# %%
# Case Folding
kalimat = [k.lower() for k in kalimat]
kalimat
# Out:
# ['elearning di pttik diatas jam 6 malam kok selalu gak bisa dibuka ya?',
#  'ub tidak punya lahan parkir yang layak. dan jalanan terlalu ramai karena di buka untuk umum. seperti jalan tol saja. brawijaya oh brawijaya',
#  'kelas arsitektur dan organisasi komputer penuh, apakah tidak dibuka kelas lagi. rugi kalo saya bisa ngambil 24 sks tapi baru 18 sks yg terpenuhi',
#  'informasi tata cara daftar ulang bagi mahasiswa baru ptiik kurang jelas. sehingga ketika tanggal terakhir syarat penyerahan berkas daftar ulang, banyak mahasiswa baru yang tidak membawa salah satu syarat daftar ulangnya.']

# %%
# Tokenization
kalimat = [k.split() for k in kalimat]
kalimat
# Out:
# [['elearning',
#   'di',
#   'pttik',
#   'diatas',
#   'jam',
#   '6',
#   'malam',
#   'kok',
#   'selalu',
#   'gak',
#   'bisa',
#   'dibuka',
#   'ya?'],
#  ['ub',
#   'tidak',
#   'punya',
#   'lahan',
#   'parkir',
#   'yang',
#   'layak.',
#   'dan',
#   'jalanan',
#   'terlalu',
#   'ramai',
#   'karena',
#   'di',
#   'buka',
#   'untuk',
#   'umum.',
#   'seperti',
#   'jalan',
#   'tol',
#   'saja.',
#   'brawijaya',
#   'oh',
#   'brawijaya'],
#  ['kelas',
#   'arsitektur',
#   'dan',
#   'organisasi',
#   'komputer',
#   'penuh,',
#   'apakah',
#   'tidak',
#   'dibuka',
#   'kelas',
#   'lagi.',
#   'rugi',
#   'kalo',
#   'saya',
#   'bisa',
#   'ngambil',
#   '24',
#   'sks',
#   'tapi',
#   'baru',
#   '18',
#   'sks',
#   'yg',
#   'terpenuhi'],
#  ['informasi',
#   'tata',
#   'cara',
#   'daftar',
#   'ulang',
#   'bagi',
#   'mahasiswa',
#   'baru',
#   'ptiik',
#   'kurang',
#   'jelas.',
#   'sehingga',
#   'ketika',
#   'tanggal',
#   'terakhir',
# ...

# %%
# Number Removal
kalimat = [[k.translate(str.maketrans("","",string.digits)) for k in kal] for kal in kalimat]
kalimat
# Out:
# [['elearning',
#   'pttik',
#   'atas',
#   'jam',
#   'malam',
#   'kok',
#   'selalu',
#   'gak',
#   'buka'],
#  ['ub',
#   'punya',
#   'lahan',
#   'parkir',
#   'layak',
#   'jalan',
#   'terlalu',
#   'ramai',
#   'buka',
#   'umum',
#   'jalan',
#   'tol',
#   'brawijaya',
#   'brawijaya'],
#  ['kelas',
#   'arsitektur',
#   'organisasi',
#   'komputer',
#   'penuh',
#   'buka',
#   'kelas',
#   'rugi',
#   'kalo',
#   'ngambil',
#   'sks',
#   'baru',
#   'sks',
#   'yg',
#   'penuh'],
#  ['informasi',
#   'tata',
#   'cara',
#   'daftar',
#   'ulang',
#   'mahasiswa',
#   'baru',
#   'ptiik',
#   'kurang',
#   'jelas',
#   'tanggal',
#   'akhir',
#   'syarat',
#   'serah',
#   'berkas',
#   'daftar',
#   'ulang',
#   'banyak',
#   'mahasiswa',
#   'baru',
#   'bawa',
#   'salah',
#   'satu',
#   'syarat',
#   'daftar',
#   'ulang']]

# %%
# Delete empty string
kalimat = [[k for k in kal if k != ''] for kal in kalimat]
kalimat
# Out:
# [['elearning',
#   'di',
#   'pttik',
#   'diatas',
#   'jam',
#   'malam',
#   'kok',
#   'selalu',
#   'gak',
#   'bisa',
#   'dibuka',
#   'ya?'],
#  ['ub',
#   'tidak',
#   'punya',
#   'lahan',
#   'parkir',
#   'yang',
#   'layak.',
#   'dan',
#   'jalanan',
#   'terlalu',
#   'ramai',
#   'karena',
#   'di',
#   'buka',
#   'untuk',
#   'umum.',
#   'seperti',
#   'jalan',
#   'tol',
#   'saja.',
#   'brawijaya',
#   'oh',
#   'brawijaya'],
#  ['kelas',
#   'arsitektur',
#   'dan',
#   'organisasi',
#   'komputer',
#   'penuh,',
#   'apakah',
#   'tidak',
#   'dibuka',
#   'kelas',
#   'lagi.',
#   'rugi',
#   'kalo',
#   'saya',
#   'bisa',
#   'ngambil',
#   'sks',
#   'tapi',
#   'baru',
#   'sks',
#   'yg',
#   'terpenuhi'],
#  ['informasi',
#   'tata',
#   'cara',
#   'daftar',
#   'ulang',
#   'bagi',
#   'mahasiswa',
#   'baru',
#   'ptiik',
#   'kurang',
#   'jelas.',
#   'sehingga',
#   'ketika',
#   'tanggal',
#   'terakhir',
#   'syarat',
#   'penyerahan',
# ...

# %%
# Punctuation Removal
kalimat = [[k.translate(str.maketrans("","",string.punctuation)) for k in kal] for kal in kalimat]
kalimat
# Out:
# [['elearning',
#   'di',
#   'pttik',
#   'diatas',
#   'jam',
#   'malam',
#   'kok',
#   'selalu',
#   'gak',
#   'bisa',
#   'dibuka',
#   'ya'],
#  ['ub',
#   'tidak',
#   'punya',
#   'lahan',
#   'parkir',
#   'yang',
#   'layak',
#   'dan',
#   'jalanan',
#   'terlalu',
#   'ramai',
#   'karena',
#   'di',
#   'buka',
#   'untuk',
#   'umum',
#   'seperti',
#   'jalan',
#   'tol',
#   'saja',
#   'brawijaya',
#   'oh',
#   'brawijaya'],
#  ['kelas',
#   'arsitektur',
#   'dan',
#   'organisasi',
#   'komputer',
#   'penuh',
#   'apakah',
#   'tidak',
#   'dibuka',
#   'kelas',
#   'lagi',
#   'rugi',
#   'kalo',
#   'saya',
#   'bisa',
#   'ngambil',
#   'sks',
#   'tapi',
#   'baru',
#   'sks',
#   'yg',
#   'terpenuhi'],
#  ['informasi',
#   'tata',
#   'cara',
#   'daftar',
#   'ulang',
#   'bagi',
#   'mahasiswa',
#   'baru',
#   'ptiik',
#   'kurang',
#   'jelas',
#   'sehingga',
#   'ketika',
#   'tanggal',
#   'terakhir',
#   'syarat',
#   'penyerahan',
#   'berkas',
# ...

# %%
pip install Sastrawi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Filtering
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Create stopword remover factory
stopword_factory = StopWordRemoverFactory()
stop_words = stopword_factory.get_stop_words()

kalimat = [[k for k in kal if k not in stop_words] for kal in kalimat]
kalimat
# Out:
# [['elearning',
#   'pttik',
#   'diatas',
#   'jam',
#   'malam',
#   'kok',
#   'selalu',
#   'gak',
#   'dibuka'],
#  ['ub',
#   'punya',
#   'lahan',
#   'parkir',
#   'layak',
#   'jalanan',
#   'terlalu',
#   'ramai',
#   'buka',
#   'umum',
#   'jalan',
#   'tol',
#   'brawijaya',
#   'brawijaya'],
#  ['kelas',
#   'arsitektur',
#   'organisasi',
#   'komputer',
#   'penuh',
#   'dibuka',
#   'kelas',
#   'rugi',
#   'kalo',
#   'ngambil',
#   'sks',
#   'baru',
#   'sks',
#   'yg',
#   'terpenuhi'],
#  ['informasi',
#   'tata',
#   'cara',
#   'daftar',
#   'ulang',
#   'mahasiswa',
#   'baru',
#   'ptiik',
#   'kurang',
#   'jelas',
#   'tanggal',
#   'terakhir',
#   'syarat',
#   'penyerahan',
#   'berkas',
#   'daftar',
#   'ulang',
#   'banyak',
#   'mahasiswa',
#   'baru',
#   'membawa',
#   'salah',
#   'satu',
#   'syarat',
#   'daftar',
#   'ulangnya']]

# %%
# Stemming
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

kalimat = [[stemmer.stem(kata) for kata in k] for k in kalimat]
kalimat
# Out:
# [['elearning',
#   'pttik',
#   'atas',
#   'jam',
#   'malam',
#   'kok',
#   'selalu',
#   'gak',
#   'buka'],
#  ['ub',
#   'punya',
#   'lahan',
#   'parkir',
#   'layak',
#   'jalan',
#   'terlalu',
#   'ramai',
#   'buka',
#   'umum',
#   'jalan',
#   'tol',
#   'brawijaya',
#   'brawijaya'],
#  ['kelas',
#   'arsitektur',
#   'organisasi',
#   'komputer',
#   'penuh',
#   'buka',
#   'kelas',
#   'rugi',
#   'kalo',
#   'ngambil',
#   'sks',
#   'baru',
#   'sks',
#   'yg',
#   'penuh'],
#  ['informasi',
#   'tata',
#   'cara',
#   'daftar',
#   'ulang',
#   'mahasiswa',
#   'baru',
#   'ptiik',
#   'kurang',
#   'jelas',
#   'tanggal',
#   'akhir',
#   'syarat',
#   'serah',
#   'berkas',
#   'daftar',
#   'ulang',
#   'banyak',
#   'mahasiswa',
#   'baru',
#   'bawa',
#   'salah',
#   'satu',
#   'syarat',
#   'daftar',
#   'ulang']]
